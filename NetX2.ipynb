# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
g=nx.read_edgelist('web-EPA.edges',create_using=nx.Graph(), nodetype= int)

# %%
print(nx.info(g))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4271
# Number of edges: 8909
# Average degree:   4.1719

# %%
type(g)
# Out:
# networkx.classes.graph.Graph

# %%
nodes = g.nodes()

# %%
# %matplotlib inline
nx.draw(g)

# %%
nx.average_clustering(g)
# Out:
# 0.07107485712587963

# %%
nx.draw_networkx(g)

# %%
nx.shortest_path(g, 1,5)
# Out:
# [1, 221, 5]

# %%
t = nx.bfs_tree(g, 3)
nx.draw(t)

# %%
nx.average_clustering(g)
# Out:
# 0.07107485712587963

# %%
nx.spring_layout(g)
# Out:
# {80: array([ 0.07097403, -0.09625704]),
#  3: array([ 0.03029234, -0.05434611]),
#  297: array([ 0.00592872, -0.03633412]),
#  298: array([ 0.03270599, -0.06869109]),
#  301: array([ 0.02482298, -0.03377217]),
#  303: array([ 0.06834961, -0.09585339]),
#  304: array([ 0.00325703, -0.08132888]),
#  306: array([ 0.01933847, -0.03391934]),
#  310: array([ 0.05607336, -0.10010059]),
#  313: array([ 0.02852338, -0.07248393]),
#  321: array([-0.01210412, -0.05319554]),
#  322: array([ 0.01556982, -0.0552394 ]),
#  328: array([ 0.03453066, -0.06014885]),
#  1059: array([ 0.03892033, -0.07221946]),
#  2900: array([ 0.00742931, -0.02699994]),
#  392: array([0.07299421, 0.09384768]),
#  5: array([0.05801666, 0.0524775 ]),
#  435: array([-0.00638796,  0.00418044]),
#  6: array([ 0.10328557, -0.03383106]),
#  437: array([ 0.06877576, -0.01971033]),
#  440: array([ 0.07384779, -0.06401934]),
#  443: array([ 0.0664211 , -0.02135216]),
#  447: array([ 0.15731263, -0.04908782]),
# ...
